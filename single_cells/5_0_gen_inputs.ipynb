# %% [markdown]
# I don't care if it's a one-to-one replication, as long as the actual output of the spike trains is functionally the same. And I do want to add the baseline input thing, but I guess if you want to test it first without it, then we can do that. The jitter we can ignore for now, but the delay stuff and the baseline before and after is definitely something we have to have for the final update for my advisor tomorrow. And so if we don't do it now, we're gonna have to change it in the next day anyways. So should we just go ahead and add that now and make it functionally the same so that the output is the same spike train generation?
