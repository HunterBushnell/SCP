# %% [markdown]
# # PV–SST Allen Cell: Local Input & Synapse Builder (ChatGPT Refactor)
#
# This notebook is the **local environment** driver for:
# - Building Allen Institute biophysical cells (PV, SST, etc.).
# - Generating structured synaptic inputs (bio-derived, background, custom).
# - Attaching synapses and spike trains using modular Python files in `modules_chatGPT/`.
#
# All NEURON cell logic and input generation live in `.py` files inside `modules_chatGPT/`.
# This notebook will only:
# 1. Configure simulation and synapse parameters.
# 2. Call the appropriate functions/classes from `modules_chatGPT/`.
# 3. Run simulations and visualize results for verification.
#
# A separate notebook will later provide a fully bootstrapped version for Google Colab or fresh environments.

# %%
"""
Cell 1 — Environment and module path setup (local version).

This cell:
- Imports core Python and scientific libraries.
- Imports NEURON.
- Ensures the `modules_chatGPT` package is importable.
- Prints basic environment info for sanity checking.
"""

import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    # NEURON import; we avoid `gui` here so this also works headless.
    from neuron import h
except ImportError as e:
    raise ImportError(
        "Could not import NEURON. Make sure NEURON is installed and available "
        "in this environment."
    ) from e

# ---------------------------------------------------------------------
# Paths
# ---------------------------------------------------------------------

# Directory containing this notebook
BASE_DIR = Path.cwd()

# Folder where we will put all refactored modules from ChatGPT
MODULES_DIR = BASE_DIR / "modules_chatGPT"

if not MODULES_DIR.exists():
    raise FileNotFoundError(
        f"Expected folder `modules_chatGPT` in {BASE_DIR}, "
        f"but it does not exist yet. Create it before proceeding."
    )

# Ensure Python can import `modules_chatGPT` as a package
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))

# Optional: verify that `modules_chatGPT` is importable as a package
try:
    import modules_chatGPT  # noqa: F401
    modules_chatGPT_available = True
except Exception:
    modules_chatGPT_available = False

# ---------------------------------------------------------------------
# Basic environment info / sanity checks
# ---------------------------------------------------------------------

print("Working directory:", BASE_DIR)
print("modules_chatGPT directory:", MODULES_DIR)
print("modules_chatGPT importable:", modules_chatGPT_available)

try:
    import neuron
    print("NEURON version:", getattr(neuron, "__version__", "unknown"))
except Exception:
    print("NEURON version: could not be determined")

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", plt.__version__)
