# %% [markdown]
# # Run cells from AllenDB

# %%
# !git clone -b release_candidate https://github.com/V-Marco/ACT.git > /dev/null 2>&1

# %% [markdown]
# #choose specimen id and model type

# %%
# Mouse L2/3 PV cell
# https://celltypes.brain-map.org/experiment/electrophysiology/484635029
specimen_id = 484635029

model_type = 'perisomatic'#or 'all active'
work_dir = 'OriginalFromAllenDB'

# %%
from allensdk.model.biophys_sim.config import Config
from allensdk.model.biophysical.utils import Utils
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("ACT")
from act.passive import ACTPassiveModule

# If error, restart env
# Out:
# /home/hrbncv/miniconda3/envs/BMTK/lib/python3.9/site-packages/torch/__init__.py:1240: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %%
from allensdk.api.queries.biophysical_api import BiophysicalApi
from allensdk.model.biophys_sim.config import Config
from allensdk.model.biophysical.utils import Utils

# %% [markdown]
# #Download the cell -  if using HOC: upload the hoc template to the working directory and modfiles into a folder named 'modfiles' and skip to 'Build the Cell' then 'Simulation Parameters'

# %% [markdown]
# #Also if using hoc, double check parameters every time build_cell() is used

# %%
#get the model id

bp = BiophysicalApi()#using AllenDB's API
models = bp.get_neuronal_models(specimen_id)

for model in models:
  if model_type in model['name'].lower():
    print(f"model id = {model['id']}\n")
    model_id = model['id']
models
# Out:
# model id = 485602029
# [{'id': 485602029,
#   'name': 'Biophysical - perisomatic_Pvalb-IRES-Cre;Ai14-201791.05.01.01',
#   'neuron_reconstruction_id': 496079599,
#   'neuronal_model_template_id': 329230710,
#   'specimen_id': 484635029},
#  {'id': 496538965,
#   'name': 'Biophysical - all active_Pvalb-IRES-Cre;Ai14-201791.05.01.01',
#   'neuron_reconstruction_id': 496079599,
#   'neuronal_model_template_id': 491455321,
#   'specimen_id': 484635029}]

# %% [markdown]
# ## Build the cell

# %% [markdown]
# if you need additonal modfiles from a public repo, provide a list of the names of the modfiles and a link to the folder

# %%
# Compile the modfiles
os.chdir(work_dir)
# !nrnivmodl modfiles > /dev/null 2>&1

# %%
import sys, os
from functools import wraps

def suppress_output(fn):
    @wraps(fn)
    def wrapper(*args, **kwargs):
        devnull = open(os.devnull, 'w')
        old_stdout, old_stderr = sys.stdout, sys.stderr
        sys.stdout = sys.stderr = devnull
        try:
            return fn(*args, **kwargs)
        finally:
            sys.stdout, sys.stderr = old_stdout, old_stderr
            devnull.close()
    return wrapper

# %% [markdown]
# **NOTE:** Control the soma area in the `build_cell` function below.

# %%
@suppress_output
def build_cell(soma_diam_multiplier = 1,using_hoc=False,hoc_filename=None,cell_name=None):

    if using_hoc:
      from neuron import h
      h.load_file(hoc_filename)
      return getattr(h, cell_name)()
    # Create the h object
    description = Config().load('manifest.json')
    utils = Utils(description)
    h = utils.h
    # Convert all "value" attributes to floats
    for dict in utils.description.data['genome']:
        for key, value in dict.items():
            if key == 'value': dict[key] = float(value)
    # Configure morphology
    morphology_path = description.manifest.get_path('MORPHOLOGY')
    utils.generate_morphology(morphology_path.encode('ascii', 'ignore'))
    utils.load_cell_parameters()
    # To match PP
    h.soma[0].diam = h.soma[0].diam * soma_diam_multiplier

    return h

def set_simulation(hoc_object,sim_params, soma_diam_multiplier = 1.0):
    from neuron import h
    h.load_file("stdrun.hoc")
    stim = h.IClamp(hoc_object.soma[0](0.5))
    stim.amp = sim_params['stim_amp']
    stim.delay = sim_params['stim_delay']
    stim.dur = sim_params['stim_dur']
    h.tstop = sim_params['h_tstop']
    h.dt = sim_params['h_dt']
    # h.steps_per_ms = 1 / h.dt
    return h, stim

# %%
soma_diam_multiplier = 1
hobject = build_cell(soma_diam_multiplier)
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %% [markdown]
# #Morphology

# %%
print(f"Soma area: {hobject.soma[0](0.5).area()}")
print(f"Soma diam: {hobject.soma[0].diam}")
print(f"Soma L: {hobject.soma[0].L}")
# Out:
# Soma area: 669.646002883916
# Soma diam: 14.599800109863281
# Soma L: 14.599853515625

# %% [markdown]
# ## Passive properties

# %%
# Soma area from the previous cell
computed_soma_area = hobject.soma[0](0.5).area() * 1e-8 #(cm2)
# User-provided desired properties
user_provided_Rin = 98.9 * 10e6 # (to Ohm from MOhm)
user_provided_tau = 5.9 * 1e-3 # (to s from ms)
user_provided_Vrest = -71.25 # (mV)
spps = ACTPassiveModule.compute_spp(user_provided_Rin, computed_soma_area, user_provided_tau, user_provided_Vrest)
print(spps)
# Out:
# SettablePassiveProperties(Cm=0.8908620098605767, g_bar_leak=0.00015099356099331808, e_rev_leak=-71.25, g_bar_h=None)

# %% [markdown]
# #set simulation parameters

# %%
sim_params = {
                'stim_amp': -0.1,
                'stim_delay': 300,
                'stim_dur': 1000,
                'h_tstop': 1500,
                'h_dt': 0.025
                }

# %% [markdown]
# #run the simulation

# %%
def count_voltage_events(t, v):
    """
    Counts the number of times the voltage goes above -20 mV and the slope changes from positive to negative.

    Args:
        t: A NumPy array of time points.
        v: A NumPy array of voltage values.

    Returns:
        The number of events.
    """

    # Calculate the slope of the voltage
    slope = np.diff(v)

    # Find the indices where the voltage is above -20 mV
    above_threshold_indices = np.where(v[:-1] > -20)[0]

    # Find the indices where the slope changes from positive to negative
    positive_to_negative_indices = np.where((slope[:-1] > 0) & (slope[1:] < 0))[0]

    # Find the intersection of the two sets of indices
    event_indices = np.intersect1d(above_threshold_indices, positive_to_negative_indices)

    return len(event_indices)

# %%
#function to get the start and end index of the stim but in the voltage file
def get_start_end_idx(sim_params):
  start_idx = int(sim_params['stim_delay']/sim_params['h_dt'])
  end_idx = int(sim_params['stim_dur']/sim_params['h_dt'])
  return start_idx, end_idx

# %%
#function to calculate the frequency of a voltage trace
def get_frequency(v,sim_params):

  start_idx,end_idx = get_start_end_idx(sim_params)
  spikes = count_voltage_events(np.arange(len(v.as_numpy()))[start_idx:end_idx], v.as_numpy()[start_idx:end_idx])

  if spikes> 0:
    duration_sec = sim_params['stim_dur'] / 1000.0
    freq = spikes / duration_sec
    return freq

  else:
    return 0

# %%
#modify simulation parameters if needed
sim_params['stim_amp'] = -0.05

sim_params['stim_delay'] = 100
sim_params['stim_dur'] = 1000
sim_params['h_tstop'] = 1500

#rebuild the cell to make sure the set_simulation() is using the correct hobj
#if using hoc call with the hoc filename and cell name

soma_diam_multiplier = 2.75
hobject = build_cell(soma_diam_multiplier)
#hobject = build_cell(soma_diam_multiplier,using_hoc=True,'HYPO_TEMPLATE.hoc','HYPO')

# run the simulation
h, stim = set_simulation(hobject,sim_params)
v = h.Vector().record(hobject.soma[0](0.5)._ref_v)
h.finitialize()
h.run()

#plot the result and display spike frequency
V = v.as_numpy()
T = np.arange(0,h.tstop+h.dt,h.dt)
plt.ylim(-90,-0)
plt.plot(T,V)
plt.grid(True)
plt.title(f"Vm at {sim_params['stim_amp']} nA")
plt.show()



#find Rin, tau, sag ratio, and Vrest
print('Desired Properties:       R_in=98.9, tau1=5.9, tau2=??.?, sag_ratio=0.960, V_rest=-71.25')
print(ACTPassiveModule.compute_gpp(v.as_numpy(), h.dt, sim_params['stim_delay'], 1290, sim_params['stim_amp']))
# Out:
# Desired Properties:       R_in=98.9, tau1=5.9, tau2=??.?, sag_ratio=0.960, V_rest=-71.25
# GettablePassiveProperties(R_in=-0.0, tau1=6.1, tau2=976.4, sag_ratio=0.924, V_rest=-71.0)

# %%
# (R_in=146.5, tau1=6.2, tau2=67.4, sag_ratio=0.998, V_rest=-70.16)

# %% [markdown]
# ## FI-Curve

# %%
#modify simulation parameters if needed
sim_params['stim_amp'] = 0.01

sim_params['stim_delay'] = 100
sim_params['stim_dur'] = 1000
sim_params['h_tstop'] = 1500

#rebuild the cell to make sure the set_simulation() is using the correct hobj
#if using hoc call with the hoc filename and cell name

soma_diam_multiplier = 2.75
hobject = build_cell(soma_diam_multiplier)
#hobject = build_cell(soma_diam_multiplier,using_hoc=True,'HYPO_TEMPLATE.hoc','HYPO')

# run the simulation
h, stim = set_simulation(hobject,sim_params)
v = h.Vector().record(hobject.soma[0](0.5)._ref_v)
h.finitialize()
h.run()

#plot the result and display spike frequency
V = v.as_numpy()
T = np.arange(0,h.tstop+h.dt,h.dt)
plt.plot(T,V)
# plt.xlim(100,200)
plt.title(f"Vm at {sim_params['stim_amp']} nA")
plt.show()

print(f"spike frequency = {get_frequency(v,sim_params):.2f} Hz")

T,V,spks = run_step(I+20)
V = v.as_numpy()
T = np.arange(0,h.tstop+h.dt,h.dt)
spks = record_voltage_events(T,V)
m = ap_metrics(T,V,spks)
print(m)   # {'pk': …, 'vth': …, 'hw': …}
# Out:
# spike frequency = 0.00 Hz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 31
#      27 plt.show()
#      29 print(f"spike frequency = {get_frequency(v,sim_params):.2f} Hz")
# ---> 31 T,V,spks = run_step(I+20)
#      32 V = v.as_numpy()
#      33 T = np.arange(0,h.tstop+h.dt,h.dt)
#
# NameError: name 'run_step' is not defined

# %%
#test the cell at multiple frequencies to get an FI curve

frequenies = []
amps = [-0.1, -0.05, 0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.275, 0.3]#, 0.4, 0.5, 0.6]

for amp in amps:
  #if using hoc call with the hoc filename and cell name
    hobject = build_cell(soma_diam_multiplier)
    #hobject = build_cell(soma_diam_multiplier,using_hoc=True,'HYPO_TEMPLATE.hoc','HYPO')

    sim_params['stim_amp'] = amp
    h, stim = set_simulation(hobject,sim_params)
    v = h.Vector().record(hobject.soma[0](0.5)._ref_v)
    h.finitialize()
    h.run()
    frequenies.append(get_frequency(v,sim_params))



for a, f in zip(amps, frequenies):
    print(f"{a}: {f}")



plt.plot(amps, frequenies)
plt.title("FI CURVE")
plt.xlabel("Stimulus Amplitude (nA)")
plt.ylabel("Frequency (Hz)")
plt.grid()
plt.show()
# Out:
# -0.1: 0
# -0.05: 0
# 0: 0
# 0.025: 0
# 0.05: 0
# 0.075: 0
# 0.1: 0
# 0.125: 2.0
# 0.15: 80.0
# 0.175: 90.0
# 0.2: 98.0
# 0.225: 105.0
# 0.25: 112.0
# 0.275: 118.0
# 0.3: 124.0

# %% [markdown]
# ChatGPT Steps

# %% [markdown]
# 0. Preparation

# %%
#modify simulation parameters if needed
sim_params['stim_amp'] = 0.1

sim_params['stim_delay'] = 100
sim_params['stim_dur'] = 1000
sim_params['h_tstop'] = 1500

#rebuild the cell to make sure the set_simulation() is using the correct hobj
#if using hoc call with the hoc filename and cell name

soma_diam_multiplier = 2.75
hobject = build_cell(soma_diam_multiplier)
#hobject = build_cell(soma_diam_multiplier,using_hoc=True,'HYPO_TEMPLATE.hoc','HYPO')

# run the simulation
h, stim = set_simulation(hobject,sim_params)
v = h.Vector().record(hobject.soma[0](0.5)._ref_v)
h.finitialize()
h.run()

#plot the result and display spike frequency
V = v.as_numpy()
T = np.arange(0,h.tstop+h.dt,h.dt)
plt.plot(T,V)
# plt.xlim(200,400)
plt.title(f"Vm at {sim_params['stim_amp']} nA")
plt.show()

print(f"spike frequency = {get_frequency(v,sim_params):.2f} Hz")
# Out:
# spike frequency = 1.00 Hz

# %% [markdown]
# 1 . “Bare-bones spiker” — tune NaTa + Kd only
#
# Goal: bring up a clean, single-spike generator that matches basic AP shape and rheobase using only NaTa (fast Na) and Kd (delayed-rectifier K). Everything else stays at gbar = 0.

# %% [markdown]
# Step 1: Zero out all active mechanisms except NaTa & Kd

# %% [markdown]
# Step 2: Select starting gbar values (NaTa=0.1, Kd=0.01)

# %% [markdown]
# Step 3: Define a short, diagnostic stimulus
#
# Keep the long FI protocol from Step 0 for later, but use a 50 ms pulse here so each iteration runs in a few ms of real time.

# %%
stim.amp   = 0      # we will sweep later
stim.delay = 5      # ms
stim.dur   = 50     # ms
h.tstop    = 60

# %% [markdown]
# Step 4: Build quick scoring functions

# %%
import numpy as np

def run_step(i_pA):
    stim.amp = i_pA*1e-3    # pA→nA
    h.finitialize(h.v_init)
    h.continuerun(h.tstop)
    t = np.array(T); v = np.array(V)
    # simple spike detector (0-mV upward crossing)
    spk_ix = np.where((v[:-1] < 0) & (v[1:] >= 0))[0]
    return t, v, spk_ix

def ap_metrics(t, v, spk_ix):
    if len(spk_ix)==0:
        return None
    pk = v[spk_ix].max()
    # threshold ≈ Vm where dV/dt crosses 20 mV/ms
    dvdt = np.gradient(v, t)
    try:
        th_ix = np.where(dvdt > 20)[0][0]
        vth   = v[th_ix]
    except IndexError:
        vth = np.nan
    # half-width
    half = 0.5*(pk+vth)
    above = np.where(v >= half)[0]
    hw_ms = (t[above[-1]] - t[above[0]]) if above.size else np.nan
    return dict(pk=pk, vth=vth, hw=hw_ms)

# %%
def record_voltage_events(t, v):

    # Calculate the slope of the voltage
    slope = np.diff(v)

    # Find the indices where the voltage is above -20 mV
    above_threshold_indices = np.where(v[:-1] > -20)[0]

    # Find the indices where the slope changes from positive to negative
    positive_to_negative_indices = np.where((slope[:-1] > 0) & (slope[1:] < 0))[0]

    # Find the intersection of the two sets of indices
    event_indices = np.intersect1d(above_threshold_indices, positive_to_negative_indices)

    return event_indices

# %% [markdown]
# Step 5:  Find rheobase & coarse-tune gnabar_NaTa
#
# 1. Sweep 50-ms steps from 10 pA up until the first spike appears (binary search is fastest).
#
# 2. Record spike peak (pk) and threshold (vth).

# %%
stim.amp = 0
stim.delay=100
stim.dur=1000
h.tstop=1200

# %%
I = 10; found=False
while not found and I < 1000:
    t,v,spks = run_step(I)
    if len(spks):
        found=True
    else:
        I += 10
print(f"Rheobase ≈ {I} pA")
# Out:
# Rheobase ≈ 1000 pA

# %% [markdown]
# Step 6: Shape the spike with gkbar_Kd
#
# Inject rheobase + 20 pA and look at half-width & AHP.

# %%
T,V,spks = run_step(I+20)
V = v.as_numpy()
T = np.arange(0,h.tstop+h.dt,h.dt)
spks = record_voltage_events(T,V)
m = ap_metrics(T,V,spks)
print(m)   # {'pk': …, 'vth': …, 'hw': …}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[202], line 2
#       1 T,V,spks = run_step(I+20)
# ----> 2 V = v.as_numpy()
#       3 T = np.arange(0,h.tstop+h.dt,h.dt)
#       4 spks = record_voltage_events(T,V)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'as_numpy'

# %%
t,v,sp = run_step(I+20)
m = ap_metrics(t,v,sp)
print(m)   # {'pk': …, 'vth': …, 'hw': …}
# Out:
# None

# %% [markdown]
# Step 7: Run the full 1 s FI protocol (from Step 0)
#
# You should get:
#
# - Rheobase within experimental range.
#
# - Linear FI rise without adaptation (plateaus at high current are okay).
#
# - No doublets, bursts, or depolarization block.
#
# If the FI slope is too shallow (Hz/pA low at high current), your Kd may be too strong—halve gkbar_Kd in distal dendrites or add an A-type later, but don’t fight it now.

# %% [markdown]
# Step 8: Freeze & Commit

# %%
print("Final gnabar_NaTa =", soma(0.5).gnabar_NaTa)
print("Final gkbar_Kd   =", soma(0.5).gkbar_Kd)

# %% [markdown]
# Trouble-shooting Crib Sheet
#
# Problem-----------------------------Primary knob------------Secondary knob
#
# Rheobase too high (> 2× data)-------↑ gnabar_NaTa-----------↓ leak g
#
# Spike fails at > 300 pA-------------↑ gkbar_Kd--------------(later) add SK / Ca
#
# Spikes broaden with current---------↑ gkbar_Kd--------------shift Kd activation left by –3 mV
#
# After-depolarization hump-----------↓ gnabar_NaTa-----------later add A-type or Ca-dependent K
