# %% [markdown]
# # Step 5 Colab Notebook Moved
#
# Use `../5_simulate.ipynb` for both local Jupyter and Google Colab runs. Step 5 now has one unified notebook with conditional Colab setup, dependency installation, repo cloning, modfile compilation, simulation, saving, and quick diagnostics.
#
# This placeholder remains only so older links fail clearly instead of silently running outdated duplicated code.
